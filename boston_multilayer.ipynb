# %% [markdown]
# <a href="https://colab.research.google.com/github/marzhira/Deeplearning_Practice/blob/main/boston_multilayer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#보스턴 집값예측
import pandas as pd
import tensorflow as tf

# %%
boston = pd.read_csv('https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv')
print(boston.columns)
boston
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')
#         crim    zn  indus  chas    nox  ...  tax  ptratio       b  lstat  medv
# 0    0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1    0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2    0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3    0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4    0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
# ..       ...   ...    ...   ...    ...  ...  ...      ...     ...    ...   ...
# 501  0.06263   0.0  11.93     0  0.573  ...  273     21.0  391.99   9.67  22.4
# 502  0.04527   0.0  11.93     0  0.573  ...  273     21.0  396.90   9.08  20.6
# 503  0.06076   0.0  11.93     0  0.573  ...  273     21.0  396.90   5.64  23.9
# ...

# %%
boston_x = boston[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
       'ptratio', 'b', 'lstat']]
boston_y = boston[['medv']]
print(boston_x.shape, boston_y.shape)
# Out:
# (506, 13) (506, 1)

# %%
#모델 생성
x = tf.keras.layers.Input(shape=[13])
h = tf.keras.layers.Dense(10, activation='swish')(x)
y = tf.keras.layers.Dense(1)(h)
model = tf.keras.models.Model(x, y)
model.compile(loss='mse')

# %%
#학습
model.fit(boston_x, boston_y, epochs=1000, verbose=0)
model.fit(boston_x, boston_y, epochs=1000)
# Out:
# Epoch 1/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 21.8999
# Epoch 2/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 26.3200
# Epoch 3/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 22.2591
# Epoch 4/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 22.4569
# Epoch 5/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 22.9442
# Epoch 6/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 23.0498
# Epoch 7/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 25.1458
# Epoch 8/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 22.7189
# Epoch 9/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 22.6985
# Epoch 10/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 25.0564
# Epoch 11/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 25.5879
# Epoch 12/1000
# ...

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_3 (InputLayer)         [(None, 13)]              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                140
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# ...
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.predict(boston_x[0:5])
# Out:
# array([[27.071518],
#        [22.541855],
#        [28.18404 ],
#        [28.102165],
#        [28.261513]], dtype=float32)

# %%
#모델의 수식 확인
model.get_weights()
# Out:
# [array([[ 0.28516284,  0.21779521,  0.41130817, -0.19191772, -0.07401732,
#           0.10179052, -0.12521078,  0.46086758,  0.09609855, -0.37815154],
#         [-0.03069362,  0.14820355, -0.10365447, -0.26023936,  0.15456125,
#          -0.18336485,  0.0068597 ,  0.02558905,  0.25784665,  0.33861583],
#         [ 0.06863441,  0.20066728,  0.16007918, -0.1292326 ,  0.15613306,
#           0.35236776, -0.03244074,  0.48207253, -0.28744808, -0.31362483],
#         [ 0.17402549,  0.27087253, -0.28484073,  0.41842452, -0.4960628 ,
#           1.8764176 , -0.7232464 ,  0.281448  , -0.21362974,  0.45958498],
#         [ 0.8365688 , -0.5755664 , -0.25672743, -0.56816417,  0.64740974,
#          -3.4443104 ,  1.1967151 , -0.2672395 ,  0.4021111 , -1.0029576 ],
#         [-2.3709555 ,  2.0609784 ,  0.03503925,  1.8354279 , -2.0968099 ,
#          -2.835719  , -2.43199   , -0.31917846, -2.0629873 ,  2.2721286 ],
#         [-0.06690858,  0.4633657 , -0.12070796, -0.4825578 , -0.18802094,
# ...
